# %% [markdown]
# https://github.com/bpbpublications/Building-Transformer-Models-with-PyTorch-2.0
#
# https://github.com/bpbpublications/Building-Generative-AI-Applications-with-Open-source-Libraries
#
# https://github.com/bpbpublications/Building-LLMs-with-PyTorch
